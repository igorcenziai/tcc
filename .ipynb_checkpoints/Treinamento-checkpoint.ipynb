# %%
# %load_ext autoreload
# %autoreload 2
    
import cv2
import numpy as np
from sklearn.utils import shuffle
import zipfile
import os
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
from utils.utils import load_dataset, download_dataset, create_cnn_model, get_callbacks, get_preds, show_train_loss_accuracy, show_metrics, INPUT_SHAPE, OUTPUT_CLASSES
# %matplotlib inline
warnings.filterwarnings('ignore')
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
DATA_PATH = "./data"
TRAIN_PATH = os.path.join(DATA_PATH, "train")
TEST_PATH = os.path.join(DATA_PATH, "test")

# %%
download_dataset(DATA_PATH)
# Out:
# ✅ Dataset já existe em: ./data
# Pulando download...

# %%
X_train, y_train, LABEL_MAP = load_dataset(TRAIN_PATH)
X_test, y_test, _ = load_dataset(TEST_PATH)

X_train.shape, y_train.shape, LABEL_MAP
# Out:
# ((28709, 48, 48, 3),
#  (28709,),
#  {'angry': 0,
#   'disgust': 1,
#   'fear': 2,
#   'happy': 3,
#   'neutral': 4,
#   'sad': 5,
#   'surprise': 6})

# %%
from tensorflow.keras.applications import VGG19, DenseNet201, ResNet50V2

resnet50v2 = create_cnn_model(
    ResNet50V2(
    include_top=False,
    weights="imagenet",
    input_shape=INPUT_SHAPE,
    pooling=None,
    classes=OUTPUT_CLASSES,
    classifier_activation="softmax"
), OUTPUT_CLASSES)

denseNet201 = create_cnn_model(DenseNet201(
    include_top=False,
    weights="imagenet",
    input_shape=INPUT_SHAPE,
    pooling=None,
    classes=OUTPUT_CLASSES,
    classifier_activation="softmax"
), OUTPUT_CLASSES)

vgg19 = create_cnn_model(VGG19(
    include_top=False,
    weights="imagenet",
    input_shape=INPUT_SHAPE,
    pooling=None,
    classes=OUTPUT_CLASSES,
    classifier_activation="softmax"
), OUTPUT_CLASSES)

models = {
    "ResNet50v2": resnet50v2,
    "DenseNet201": denseNet201,
    "VGG19": vgg19,
}
# Out:
# 2025-09-11 20:03:29.234480: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)

# %%
from tensorflow.keras.utils import to_categorical

BATCH_SIZE = 32
EPOCHS = 60
histories = {}

# Normaliza
X_train_resized = X_train.astype("float32") / 255.0
X_test_resized = X_test.astype("float32") / 255.0

# One-hot
y_train_cat = to_categorical(y_train, num_classes=OUTPUT_CLASSES)
y_test_cat = to_categorical(y_test, num_classes=OUTPUT_CLASSES)

for model_name, model in models.items():
    print(f"STRAT TRAINING MODEL {model_name}...")
    histories[model_name] = model.fit(X_train_resized, y_train_cat,
                                     validation_split=0.2,
                                     epochs=EPOCHS,
                                     batch_size=BATCH_SIZE,
                                     callbacks=get_callbacks(model_name))
    print(f"FINISH TRAINING MODEL {model_name}!")
    print("---------------------------------------------------------------")
# Out:
# STRAT TRAINING MODEL ResNet50v2...
# Epoch 1/60
# 2025-09-11 20:04:45.916598: W external/local_xla/xla/tsl/framework/cpu_allocator_impl.cc:84] Allocation of 634991616 exceeds 10% of free system memory.
# 717/718 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.1961 - loss: 3.2218
# 2025-09-11 20:05:33.576304: W external/local_xla/xla/tsl/framework/cpu_allocator_impl.cc:84] Allocation of 158754816 exceeds 10% of free system memory.
# 718/718 ━━━━━━━━━━━━━━━━━━━━ 60s 76ms/step - accuracy: 0.2247 - loss: 2.7917 - val_accuracy: 0.2957 - val_loss: 1.9220 - learning_rate: 1.0000e-04
# Epoch 2/60
# 718/718 ━━━━━━━━━━━━━━━━━━━━ 54s 75ms/step - accuracy: 0.2732 - loss: 2.1679 - val_accuracy: 0.3312 - val_loss: 1.7669 - learning_rate: 1.0000e-04
# Epoch 3/60
# 718/718 ━━━━━━━━━━━━━━━━━━━━ 52s 73ms/step - accuracy: 0.3039 - loss: 1.9433 - val_accuracy: 0.3459 - val_loss: 1.7011 - learning_rate: 1.0000e-04
# Epoch 4/60
# 718/718 ━━━━━━━━━━━━━━━━━━━━
W external/local_xla/xla/tsl/framework/cpu_allocator_impl.cc:84] Allocation of 634991616 exceeds 10% of free system memory.
# 718/718 ━━━━━━━━━━━━━━━━━━━━ 144s 199ms/step - accuracy: 0.1988 - loss: 1.9779 - val_accuracy: 0.2679 - val_loss: 1.7763 - learning_rate: 1.0000e-04
# Epoch 2/60
# 718/718 ━━━━━━━━━━━━━━━━━━━━ 142s 198ms/step - accuracy: 0.2508 - loss: 1.8176 - val_accuracy: 0.3102 - val_loss: 1.7133 - learning_rate: 1.0000e-04
# Epoch 3/60
# 718/718 ━━━━━━━━━━━━━━━━━━━━ 142s 198ms/step - accuracy: 0.2797 - loss: 1.7651 - val_accuracy: 0.3292 - val_loss: 1.6820 - learning_rate: 1.0000e-04
# Epoch 4/60
# 718/718 ━━━━━━━━━━━━━━━━━━━━ 142s 198ms/step - accuracy: 0.3031 - loss: 1.7253 - val_accuracy: 0.3389 - val_loss: 1.6621 - learning_rate: 1.0000e-04
# Epoch 5/60
# 718/718 ━━━━━━━━━━━━━━━━━━━━ 144s 200ms/step - accuracy: 0.3131 - loss: 1.7107 - val_accuracy: 0.3438 - val_loss: 1.6508 - learning_rate: 1.0000e-04
# Epoch 6/60
# 718/718 ━━━━━━━━━━━━━━━━━━━━ 142s 198ms/step - accuracy: 0.3195 - loss: 1.6909 - val_accuracy: 0.3495 - val_loss: 1.6407 - learning_rate: 1.0000e-04
# Epoch 7/60
# 718/718 ━━━━━━━━━━━━━━━━━━━━ 142s 198ms/step - accuracy: 0.3296 - loss: 1.6776 - val_accuracy: 0.3497 - val_loss: 1.6339 - learning_rate: 1.0000e-04
# Epoch 8/60
# 718/718 ━━━━━━━━━━━━━━━━━━━━ 142s 198ms/step - accuracy: 0.3353 - loss: 1.6703 - val_accuracy: 0.3527 - val_loss: 1.6274 - learning_rate: 1.0000e-04
# Epoch 9/60
# 718/718 ━━━━━━━━━━━━━━━━━━━━ 142s 198ms/step - accuracy: 0.3385 - loss: 1.6622 - val_accuracy: 0.3624 - val_loss: 1.6225 - learning_rate: 1.0000e-04
# Epoch 10/60
# 718/718 ━━━━━━━━━━━━━━━━━━━━ 142s 197ms/step - accuracy: 0.3371 - loss: 1.6596 - val_accuracy: 0.3635 - val_loss: 1.6186 - learning_rate: 1.0000e-04
# Epoch 11/60
# 718/718 ━━━━━━━━━━━━━━━━━━━━ 142s 198ms/step - accuracy: 0.3422 - loss: 1.6533 - val_accuracy: 0.3642 - val_loss: 1.6156 - learning_rate: 1.0000e-04
# Epoch 12/60
# 718/718 ━━━━━━━━━━━━━━━━━━━━ 144s 201ms/step - accuracy: 0.3433 - loss: 1.6466 - val_accuracy: 0.3617 - val_loss: 1.6128 - learning_rate: 1.0000e-04
# Epoch 13/60
# 718/718 ━━━━━━━━━━━━━━━━━━━━ 142s 198ms/step - accuracy: 0.3489 - loss: 1.6438 - val_accuracy: 0.3643 - val_loss: 1.6088 - learning_rate: 1.0000e-04
# Epoch 14/60
# 718/718 ━━━━━━━━━━━━━━━━━━━━ 143s 199ms/step - accuracy: 0.3508 - loss: 1.6383 - val_accuracy: 0.3697 - val_loss: 1.6062 - learning_rate: 1.0000e-04
# Epoch 15/60
# 718/718 ━━━━━━━━━━━━━━━━━━━━ 142s 198ms/step - accuracy: 0.3506 - loss: 1.6359 - val_accuracy: 0.3662 - val_loss: 1.6061 - learning_rate: 1.0000e-04
# Epoch 16/60
# 718/718 ━━━━━━━━━━━━━━━━━━━━ 142s 198ms/step - accuracy: 0.3504 - loss: 1.6321 - val_accuracy: 0.3736 - val_loss: 1.6019 - learning_rate: 1.0000e-04
# Epoch 17/60
# 718/718 ━━━━━━━━━━━━━━━━━━━━ 142s 198ms/step - accuracy: 0.3549 - loss: 1.6308 - val_accuracy: 0.3687 - val_loss: 1.6004 - learning_rate: 1.0000e-04
# Epoch 18/60
# 718/718 ━━━━━━━━━━━━━━━━━━━━ 60623s 85s/step - accuracy: 0.3552 - loss: 1.6281 - val_accuracy: 0.3682 - val_loss: 1.5993 - learning_rate: 1.0000e-04
# Epoch 19/60
# 718/718 ━━━━━━━━━━━━━━━━━━━━ 208s 290ms/step - accuracy: 0.3608 - loss: 1.6261 - val_accuracy: 0.3704 - val_loss: 1.5973 - learning_rate: 1.0000e-04
# Epoch 20/60
# 718/718 ━━━━━━━━━━━━━━━━━━━━ 201s 279ms/step - accuracy: 0.3591 - loss: 1.6251 - val_accuracy: 0.3758 - val_loss: 1.5961 - learning_rate: 1.0000e-04
# Epoch 21/60
# 718/718 ━━━━━━━━━━━━━━━━━━━━ 195s 272ms/step - accuracy: 0.3563 - loss: 1.6225 - val_accuracy: 0.3758 - val_loss: 1.5959 - learning_rate: 1.0000e-04
# Epoch 22/60
# 718/718 ━━━━━━━━━━━━━━━━━━━━ 195s 272ms/step - accuracy: 0.3620 - loss: 1.6217 - val_accuracy: 0.3791 - val_loss: 1.5933 - learning_rate: 1.0000e-04
# Epoch 23/60
# 718/718 ━━━━━━━━━━━━━━━━━━━━ 195s 272ms/step - accuracy: 0.3603 - loss: 1.6184 - val_accuracy: 0.3798 - val_loss: 1.5917 - learning_rate: 1.0000e-04
# Epoch 24/60
# 718/718 ━━━━━━━━━━━━━━━━━━━━ 196s 273ms/step - accuracy: 0.3585 - loss: 1.6183 - val_accuracy: 0.3767 - val_loss: 1.5909 - learning_rate: 1.0000e-04
# Epoch 25/60
# 718/718 ━━━━━━━━━━━━━━━━━━━━ 169s 236ms/step - accuracy: 0.3596 - loss: 1.6185 - val_accuracy: 0.3793 - val_loss: 1.5893 - learning_rate: 1.0000e-04
# Epoch 26/60
# 718/718 ━━━━━━━━━━━━━━━━━━━━ 143s 200ms/step - accuracy: 0.3620 - loss: 1.6149 - val_accuracy: 0.3805 - val_loss: 1.5889 - learning_rate: 1.0000e-04
# Epoch 27/60
# 718/718 ━━━━━━━━━━━━━━━━━━━━ 143s 200ms/step - accuracy: 0.3642 - loss: 1.6178 - val_accuracy: 0.3797 - val_loss: 1.5886 - learning_rate: 1.0000e-04
# Epoch 28/60
# 718/718 ━━━━━━━━━━━━━━━━━━━━ 143s 200ms/step - accuracy: 0.3589 - loss: 1.6111 - val_accuracy: 0.3826 - val_loss: 1.5877 - learning_rate: 1.0000e-04
# Epoch 29/60
# 718/718 ━━━━━━━━━━━━━━━━━━━━ 144s 201ms/step - accuracy: 0.3633 - loss: 1.6148 - val_accuracy: 0.3790 - val_loss: 1.5874 - learning_rate: 1.0000e-04
# Epoch 30/60
# 718/718 ━━━━━━━━━━━━━━━━━━━━ 144s 200ms/step - accuracy: 0.3628 - loss: 1.6118 - val_accuracy: 0.3788 - val_loss: 1.5890 - learning_rate: 1.0000e-04
# Epoch 31/60
# 718/718 ━━━━━━━━━━━━━━━━━━━━ 144s 200ms/step - accuracy: 0.3655 - loss: 1.6093 - val_accuracy: 0.3837 - val_loss: 1.5854 - learning_rate: 1.0000e-04
# Epoch 32/60
# 718/718 ━━━━━━━━━━━━━━━━━━━━ 144s 200ms/step - accuracy: 0.3660 - loss: 1.6096 - val_accuracy: 0.3797 - val_loss: 1.5858 - learning_rate: 1.0000e-04
# Epoch 33/60
# 718/718 ━━━━━━━━━━━━━━━━━━━━ 143s 200ms/step - accuracy: 0.3609 - loss: 1.6138 - val_accuracy: 0.3805 - val_loss: 1.5847 - learning_rate: 1.0000e-04
# Epoch 34/60
# 718/718 ━━━━━━━━━━━━━━━━━━━━ 144s 200ms/step - accuracy: 0.3690 - loss: 1.6064 - val_accuracy: 0.3819 - val_loss: 1.5837 - learning_rate: 1.0000e-04
# Epoch 35/60
# 718/718 ━━━━━━━━━━━━━━━━━━━━ 143s 200ms/step - accuracy: 0.3666 - loss: 1.6101 - val_accuracy: 0.3814 - val_loss: 1.5845 - learning_rate: 1.0000e-04
# Epoch 36/60
# 718/718 ━━━━━━━━━━━━━━━━━━━━ 143s 200ms/step - accuracy: 0.3686 - loss: 1.6075 - val_accuracy: 0.3765 - val_loss: 1.5843 - learning_rate: 1.0000e-04
# Epoch 37/60
# 718/718 ━━━━━━━━━━━━━━━━━━━━ 143s 200ms/step - accuracy: 0.3666 - loss: 1.6035 - val_accuracy: 0.3863 - val_loss: 1.5829 - learning_rate: 1.0000e-04
# Epoch 38/60
# 718/718 ━━━━━━━━━━━━━━━━━━━━ 144s 201ms/step - accuracy: 0.3706 - loss: 1.6048 - val_accuracy: 0.3826 - val_loss: 1.5832 - learning_rate: 1.0000e-04
# Epoch 39/60
# 718/718 ━━━━━━━━━━━━━━━━━━━━ 144s 200ms/step - accuracy: 0.3670 - loss: 1.6065 - val_accuracy: 0.3887 - val_loss: 1.5816 - learning_rate: 1.0000e-04
# Epoch 40/60
# 718/718 ━━━━━━━━━━━━━━━━━━━━ 144s 200ms/step - accuracy: 0.3654 - loss: 1.6047 - val_accuracy: 0.3835 - val_loss: 1.5805 - learning_rate: 1.0000e-04
# Epoch 41/60
# 718/718 ━━━━━━━━━━━━━━━━━━━━ 144s 200ms/step - accuracy: 0.3678 - loss: 1.6067 - val_accuracy: 0.3885 - val_loss: 1.5800 - learning_rate: 1.0000e-04
# Epoch 42/60
# 718/718 ━━━━━━━━━━━━━━━━━━━━ 144s 200ms/step - accuracy: 0.3627 - loss: 1.6056 - val_accuracy: 0.3854 - val_loss: 1.5801 - learning_rate: 1.0000e-04
# Epoch 43/60
# 718/718 ━━━━━━━━━━━━━━━━━━━━ 144s 200ms/step - accuracy: 0.3677 - loss: 1.6028 - val_accuracy: 0.3826 - val_loss: 1.5804 - learning_rate: 1.0000e-04
# Epoch 44/60
# 718/718 ━━━━━━━━━━━━━━━━━━━━ 144s 201ms/step - accuracy: 0.3673 - loss: 1.6018 - val_accuracy: 0.3844 - val_loss: 1.5789 - learning_rate: 1.0000e-04
# Epoch 45/60
# 718/718 ━━━━━━━━━━━━━━━━━━━━ 144s 200ms/step - accuracy: 0.3672 - loss: 1.6014 - val_accuracy: 0.3854 - val_loss: 1.5795 - learning_rate: 1.0000e-04
# Epoch 46/60
# 718/718 ━━━━━━━━━━━━━━━━━━━━ 144s 201ms/step - accuracy: 0.3708 - loss: 1.5994 - val_accuracy: 0.3866 - val_loss: 1.5785 - learning_rate: 1.0000e-04
# Epoch 47/60
# 718/718 ━━━━━━━━━━━━━━━━━━━━ 144s 201ms/step - accuracy: 0.3694 - loss: 1.6032 - val_accuracy: 0.3840 - val_loss: 1.5776 - learning_rate: 1.0000e-04
# Epoch 48/60
# 718/718 ━━━━━━━━━━━━━━━━━━━━ 144s 201ms/step - accuracy: 0.3722 - loss: 1.6026 - val_accuracy: 0.3884 - val_loss: 1.5774 - learning_rate: 1.0000e-04
# Epoch 49/60
# 718/718 ━━━━━━━━━━━━━━━━━━━━ 144s 201ms/step - accuracy: 0.3712 - loss: 1.6001 - val_accuracy: 0.3878 - val_loss: 1.5772 - learning_rate: 1.0000e-04
# Epoch 50/60
# 718/718 ━━━━━━━━━━━━━━━━━━━━ 144s 201ms/step - accuracy: 0.3677 - loss: 1.6034 - val_accuracy: 0.3873 - val_loss: 1.5769 - learning_rate: 1.0000e-04
# Epoch 51/60
# 718/718 ━━━━━━━━━━━━━━━━━━━━ 144s 201ms/step - accuracy: 0.3687 - loss: 1.5995 - val_accuracy: 0.3892 - val_loss: 1.5768 - learning_rate: 1.0000e-04
# Epoch 52/60
# 718/718 ━━━━━━━━━━━━━━━━━━━━ 157s 219ms/step - accuracy: 0.3701 - loss: 1.5992 - val_accuracy: 0.3824 - val_loss: 1.5771 - learning_rate: 1.0000e-04
# Epoch 53/60
# 718/718 ━━━━━━━━━━━━━━━━━━━━ 144s 201ms/step - accuracy: 0.3687 - loss: 1.6022 - val_accuracy: 0.3833 - val_loss: 1.5765 - learning_rate: 1.0000e-04
# Epoch 54/60
# 718/718 ━━━━━━━━━━━━━━━━━━━━ 145s 201ms/step - accuracy: 0.3704 - loss: 1.5983 - val_accuracy: 0.3884 - val_loss: 1.5762 - learning_rate: 1.0000e-04
# Epoch 55/60
# 718/718 ━━━━━━━━━━━━━━━━━━━━ 144s 201ms/step - accuracy: 0.3677 - loss: 1.6005 - val_accuracy: 0.3863 - val_loss: 1.5758 - learning_rate: 1.0000e-04
# Epoch 56/60
# 718/718 ━━━━━━━━━━━━━━━━━━━━ 145s 202ms/step - accuracy: 0.3748 - loss: 1.5979 - val_accuracy: 0.3847 - val_loss: 1.5761 - learning_rate: 1.0000e-04
# Epoch 57/60
# 718/718 ━━━━━━━━━━━━━━━━━━━━ 144s 201ms/step - accuracy: 0.3647 - loss: 1.5960 - val_accuracy: 0.3891 - val_loss: 1.5749 - learning_rate: 1.0000e-04
# Epoch 58/60
# 718/718 ━━━━━━━━━━━━━━━━━━━━ 145s 201ms/step - accuracy: 0.3744 - loss: 1.5952 - val_accuracy: 0.3863 - val_loss: 1.5747 - learning_rate: 1.0000e-04
# Epoch 59/60
# 718/718 ━━━━━━━━━━━━━━━━━━━━ 144s 201ms/step - accuracy: 0.3687 - loss: 1.6008 - val_accuracy: 0.3856 - val_loss: 1.5755 - learning_rate: 1.0000e-04
# Epoch 60/60
# 718/718 ━━━━━━━━━━━━━━━━━━━━ 145s 202ms/step - accuracy: 0.3721 - loss: 1.5991 - val_accuracy: 0.3854 - val_loss: 1.5746 - learning_rate: 1.0000e-04
# FINISH TRAINING MODEL VGG19!
# ---------------------------------------------------------------

# %%
for model_name, history in histories.items():
    show_train_loss_accuracy(history, model_name)

# %%
y_preds = {}
for model_name, model in models.items():
    y_preds[model_name] = get_preds(X_train_resized, model)
# Out:
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 53s 58ms/step
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 91s 96ms/step
# 898/898 ━━━━━━━━━━━━━━━━━━━━ 141s 157ms/step

# %%
metrics = {}
for model_name, preds in y_preds.items():
    metrics[model_name] = show_metrics(y_train, preds, model_name, "confusion_matrix_completa", LABEL_MAP)
# Out:
# {'angry': 0, 'disgust': 1, 'fear': 2, 'happy': 3, 'neutral': 4, 'sad': 5, 'surprise': 6}
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[37], line 4
#       2 print(LABEL_MAP)
#       3 for model_name, preds in y_preds.items():
# ----> 4     metrics[model_name] = show_metrics(y_train, preds, model_name, "confusion_matrix_completa", LABEL_MAP)
#
# File ~/Área de trabalho/Aulas/tcc/utils/utils.py:143, in show_metrics(y_true, y_pred, model_name, image_name, is_test)
#     141 def show_metrics(y_true, y_pred, model_name, image_name, is_test=False):
#     142     classes_emocao = list(LABEL_MAP.keys())
# --> 143     class_acc = {}
#     145     acc = accuracy_score(y_true, y_pred)
#     146     prec = precision_score(y_true, y_pred, average='macro')
#
# NameError: name 'LABEL_MAP' is not defined

# %%
y_preds_teste = {}
for model_name, model in models.items():
    y_preds_teste[model_name] = get_preds(X_test_resized, model)

# %%
metrics_teste = {}
for model_name, preds in y_preds_teste.items():
    metrics_teste[model_name] = show_metrics(y_test, preds, model_name, is_test=True)
